# %%
from IPython.display import IFrame
IFrame('https://www.codepuzzle.io/IP9NL2', width='100%', height=600)

# %%
from IPython.display import IFrame
IFrame('https://pythontutor.com/visualize.html#mode=edit', width='100%', height=600)
# Out:
# <iframe src="https://pythontutor.com/visualize.html#mode=edit" allowfullscreen="" width="100%" height="600" frameborder="0"></iframe>

# %%
Famille_Simpson = {'père':'Homer','mère':'Marge','fils':'Bart','fille':'Lisa','bébé':'Maggie','grand-père':'Abraham'}
# Dans la famille Simpson, je demande : le père..
List_Famille_Simpson = list(Famille_Simpson)

print(Famille_Simpson['père'])
print(List_Famille_Simpson)
for a in range(len(List_Famille_Simpson)):
    titre = List_Famille_Simpson[a]
    prenom = Famille_Simpson[List_Famille_Simpson[a]]
    print(titre, ":",prenom)
# Out:
# Homer
# ['père', 'mère', 'fils', 'fille', 'bébé', 'grand-père']
# père : Homer
# mère : Marge
# fils : Bart
# fille : Lisa
# bébé : Maggie
# grand-père : Abraham
